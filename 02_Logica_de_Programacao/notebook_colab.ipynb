# %% [markdown]
# # Semana 02 — Lógica de Programação
#
# **Curso:** Análise de Dados com Python — SENAI (Turma T5)
# **UC (MSEP):** Manipulação de Dados com Python e SQL (150h) — Bloco 1, Semanas 01 e 02
#
# Na semana passada você só deu uma espiada em código. A partir de hoje, você programa de verdade: variáveis, tipos de dados, operadores e as estruturas que controlam o que o seu programa faz.
#
# > Em cada tópico abaixo: **2 exemplos resolvidos** + **1 atividade prática** para você fazer sozinho(a). Não pule os exemplos — rode cada célula, leia o que ela faz, e só depois vá para a prática.

# %% [markdown]
# ## 1. Variáveis e Tipos de Dados
#
# | Tipo | O que guarda | Exemplo |
# |---|---|---|
# | `int` | Número inteiro | `idade = 30` |
# | `float` | Número decimal | `altura = 1.75` |
# | `str` | Texto | `nome = "Ana"` |
# | `bool` | Verdadeiro ou falso | `ativo = True` |
#
# > 💡 `=` guarda um valor (atribuição). `==` compara dois valores. Não confunda os dois!
#
# ### 🔹 Exemplo 1 — Cadastro simples

# %%
nome = "Mariana"
idade = 28
altura = 1.68
esta_matriculada = True

print(nome, idade, altura, esta_matriculada)
print(type(nome), type(idade), type(altura), type(esta_matriculada))

# %% [markdown]
# ### 🔹 Exemplo 2 — Convertendo o tipo de um dado
#
# Às vezes um número chega como texto (ex.: digitado em um formulário) e você precisa converter para poder calcular com ele.

# %%
idade_texto = "25"               # chegou como texto
idade_numero = int(idade_texto)  # convertendo para número

print(idade_numero + 1)          # agora dá para somar: 26

# %% [markdown]
# ### ✏️ Atividade Prática 1 — Sua vez de programar
#
# Crie **3 variáveis suas** (uma `int`, uma `float` e uma `str`) e confirme o tipo de cada uma com `type()`.
#
# > ⚠️ **Cuidado com o `...`:** nas células abaixo você vai ver `minha_idade = ...` — o `...` é só um marcador "substitua aqui". Se você esquecer de trocar e executar mesmo assim, o Python **não vai dar erro** (o `...` é um valor válido, chamado *Ellipsis*) — o código roda e mostra algo sem sentido. Sempre leia a saída e confira se faz sentido, mesmo sem mensagem de erro.

# %%
# Substitua pelos seus próprios dados

minha_idade = ...      # exemplo: 25
minha_altura = ...      # exemplo: 1.70
meu_nome = ...      # exemplo: "Seu Nome"

print(minha_idade, type(minha_idade))
print(minha_altura, type(minha_altura))
print(meu_nome, type(meu_nome))

# %% [markdown]
# ---
# ## 2. Operadores Aritméticos
#
# Agora que você sabe guardar dados em variáveis (seção 1), o próximo passo é fazer contas com eles.
#
# ```
# +   soma
# -   subtração
# *   multiplicação
# /   divisão (sempre decimal)
# //  divisão inteira
# %   resto da divisão (módulo)
# **  potência
# ```
#
# ### 🔹 Exemplo 1 — Conta dividida entre amigos

# %%
conta_total = 150.0
numero_de_amigos = 4

valor_por_pessoa = conta_total / numero_de_amigos
print(f"Cada um paga R$ {valor_por_pessoa}")

# %% [markdown]
# > 💡 **E se a conta não dividir certo?** Troque `numero_de_amigos` para `3` na célula acima e rode de novo: o resultado vira `33.333333333333336`, em vez de um número redondo. Isso é normal — é assim que computadores representam números decimais, em qualquer linguagem, não é um erro seu nem do Python. Se quiser um valor mais "limpo", use `round(valor_por_pessoa, 2)`.

# %% [markdown]
# ### 🔹 Exemplo 2 — Par ou ímpar com módulo

# %%
numero = 17
resto = numero % 2

print(f"O resto da divisão de {numero} por 2 é {resto}")
print("É par" if resto == 0 else "É ímpar")

# %% [markdown]
# ### ✏️ Atividade Prática 2 — Sua vez de programar
#
# Dado um `preco` de sua escolha, calcule o preço com 10% de desconto.

# %%
preco = ...   # escolha um valor, ex.: 49.90

# calcule o preço com 10% de desconto
preco_com_desconto = ...

print(f"Preço original: {preco}")
print(f"Preço com desconto: {preco_com_desconto}")

# %% [markdown]
# ---
# ## 3. Operadores Relacionais e Lógicos
#
# Os operadores da seção 2 produzem **números**. Os operadores desta seção são diferentes: produzem `True` ou `False` — e é esse `True`/`False` que vai permitir que seu programa **decida** algo, na seção 4.
#
# Operadores **relacionais** comparam valores e sempre resultam em `True` ou `False`. Operadores **lógicos** combinam várias comparações.
#
# ```
# ==  !=        igual a / diferente de
# >   <         maior que / menor que
# >=  <=        maior ou igual / menor ou igual
#
# and           verdadeiro só se AMBOS os lados forem verdadeiros
# or            verdadeiro se PELO MENOS UM lado for verdadeiro
# not           inverte o valor
# ```
#
# ### 🔹 Exemplo 1 — Verificando maioridade

# %%
idade = 16
print(idade >= 18)   # False

# %% [markdown]
# ### 🔹 Exemplo 2 — Combinando condições com "and"

# %%
idade = 20
tem_carteira = True

pode_dirigir = idade >= 18 and tem_carteira
print(f"Pode dirigir? {pode_dirigir}")

# %% [markdown]
# ### ✏️ Atividade Prática 3 — Sua vez de programar
#
# Crie `nota1` e `nota2` e use `and` para verificar se a pessoa passou em **ambas** (nota ≥ 7 nas duas).

# %%
nota1 = ...   # escolha um valor, ex.: 8.5
nota2 = ...   # escolha um valor, ex.: 6.0

passou_nas_duas = ...   # use o operador and

print(f"Passou nas duas matérias? {passou_nas_duas}")

# %% [markdown]
# ---
# ## 4. Estruturas Condicionais (if / elif / else)
#
# Lembra de comparar valores e obter `True`/`False` na seção 3? Agora você vai usar exatamente isso dentro de um `if`, para fazer seu programa escolher um caminho.
#
# ```python
# if condicao_1:
#     # executa se condicao_1 for True
# elif condicao_2:
#     # executa se condicao_1 for False e condicao_2 for True
# else:
#     # executa se nenhuma condição anterior for True
# ```
#
# > 💡 O bloco de cada condição precisa estar **indentado** (4 espaços) — é a indentação que diz ao Python o que pertence a cada bloco.
#
# ### 🔹 Exemplo 1 — Classificando uma nota

# %% [markdown]
# > ⚠️ **Veja como é um erro real do Python.** Na célula abaixo, remova o `#` do início das três linhas e execute — você vai ver um `SyntaxError: expected ':'`, porque o `if` ficou sem o `:` no final. Não é "quebrar o código": é o Python avisando exatamente onde está o problema. Leia sempre a **última linha** da mensagem de erro primeiro — ela quase sempre diz o que falta.

# %%
# idade = 18
# if idade >= 18
#     print("Maior de idade")

# %%
nota = 7.5

if nota >= 9:
    print("Excelente")
elif nota >= 7:
    print("Bom")
elif nota >= 5:
    print("Regular")
else:
    print("Insuficiente")

# %% [markdown]
# ### 🔹 Exemplo 2 — Calculando e depois classificando
#
# Nos exemplos anteriores a condição sempre comparava uma variável já pronta (`nota`). Mas você também pode **calcular um valor primeiro** e só depois classificá-lo — esse é o padrão que você vai usar com frequência em análise de dados:

# %%
renda_mensal = 3000
gasto_planejado = 900

razao = gasto_planejado / renda_mensal   # calcula primeiro...

if razao <= 0.30:                        # ...e só depois classifica
    print("Gasto dentro do limite recomendado (até 30% da renda)")
elif razao <= 0.50:
    print("Gasto no limite de atenção (30% a 50% da renda)")
else:
    print("Gasto acima do recomendado (mais de 50% da renda)")

# %% [markdown]
# ### ✏️ Atividade Prática 4 — Sua vez de programar
#
# Dada uma `idade`, classifique em "Criança" (até 12), "Adolescente" (13–17) ou "Adulto" (18+).

# %%
idade = ...   # escolha um valor

if ...:
    print("Criança")
elif ...:
    print("Adolescente")
else:
    print("Adulto")

# %% [markdown]
# ---
# ## 5. Estruturas de Repetição (for / while)
#
# Com `if`/`elif`/`else` (seção 4) seu programa já decide um caminho — mas só uma vez. Agora você vai repetir uma ação várias vezes, sem copiar e colar o mesmo código.
#
# Use `for` quando você já sabe quantas vezes quer repetir. Use `while` quando a repetição depende de uma condição que pode mudar.
#
# ### 🔹 Exemplo 1 — Contando com for

# %%
estoque_maximo = 500
estoque_atual = 80

nivel_estoque = estoque_atual / estoque_maximo   # calcula o nível primeiro...

if nivel_estoque >= 0.5:                          # ...e só depois classifica
    print("Estoque adequado — sem ação necessária")
elif nivel_estoque >= 0.2:
    print("Estoque baixo — fazer pedido de reposição")
else:
    print("Estoque crítico — reposição urgente!")

# %% [markdown]
# ### 🔹 Exemplo 2 — Contagem regressiva com while

# %%
contador = 5

while contador > 0:
    print(contador)
    contador = contador - 1

print("Lançamento!")

# %% [markdown]
# ### ✏️ Atividade Prática 5 — Sua vez de programar
#
# Use `for` para percorrer os números de 1 a 10 e imprimir apenas os números pares (use o operador `%`).

# %%
for numero in range(1, 11):
    if ...:
        print(numero)

# %% [markdown]
# ---
# ## 6. Treino em Squads — Sexta-feira (Encontro 3)
#
# Esta seção é usada **em sala (ou em salas remotas/breakout)** na sexta-feira. A turma se divide em squads, e cada squad recebe um mini-desafio de lógica diferente:
#
# | Squad | Mini-desafio |
# |---|---|
# | B | Classificador de IMC (calcular e classificar com `if`/`elif`/`else`) |
# | C | Verificador de senha simplificado (você recebe a *quantidade de caracteres* e se ela *tem número* já prontos em variáveis — combine os dois com `and`) |
# | D | Inspetor de produção (percorrer peças numeradas de 1 a 50 com `for` e contar quantas são múltiplas de 7, ou seja, defeituosas) |
# | E | Caixa eletrônico simplificado (repetir saques com `while` até digitar 0) |
#
# Resolva o desafio do seu squad na célula abaixo antes de apresentar a lógica (não só o resultado) para a turma.

# %%
# Template do squad — substitua pelo mini-desafio recebido (B, C, D ou E)

desafio_do_squad = "..."   # cole aqui o desafio recebido
print("Desafio:", desafio_do_squad)

# escreva sua solução abaixo

# %% [markdown]
# ### 🗣️ Debate coletivo (após as apresentações)
#
# Depois que todos os squads apresentarem, discuta com a turma:
#
# - Algum desafio dava para resolver com `for` **e** com `while`? Qual ficou mais legível?
# - Qual squad usou a lógica mais elegante?
# - O que esses 4 desafios têm em comum como problema de lógica?

# %% [markdown]
# ### Desafio (opcional)
#
# Resolva o exercício **FizzBuzz**: percorra os números de 1 a 20 e, para cada um, imprima se ele é múltiplo de 3, de 5, de ambos ("FizzBuzz") ou de nenhum dos dois.

# %% [markdown]
# ## 6. Treino em Squads — Sexta-feira (Encontro 3)
#
# Esta seção é usada **em sala (ou em salas remotas/breakout)** na sexta-feira. A turma se divide em squads, e cada squad recebe um mini-desafio de lógica diferente:
#
# | Squad | Mini-desafio |
# |---|---|
# | B | Classificador de IMC (calcular e classificar com `if`/`elif`/`else`) |
# | C | Verificador de senha simplificado (você recebe a *quantidade de caracteres* e se ela *tem número* já prontos em variáveis — combine os dois com `and`) |
# | D | Inspetor de produção (percorrer peças numeradas de 1 a 50 com `for` e contar quantas são múltiplas de 7, ou seja, defeituosas) |
# | E | Caixa eletrônico simplificado: comece com `saldo = 1000` e `valor_saque = 200` — use `while` para repetir os saques enquanto o saldo for suficiente e imprima o saldo restante após cada operação |
#
# Resolva o desafio do seu squad na célula abaixo antes de apresentar a lógica (não só o resultado) para a turma.
